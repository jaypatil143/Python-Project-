# %% [markdown]
# <a href="https://colab.research.google.com/github/jaypatil143/Python-Project-/blob/main/my_play_store_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -  **Play Store Apps Analysis**

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# #**DESCRIPTION =**

# %% [markdown]
# # The Google Play Store apps data analysis provides enough potential to drive apps making businesses to succeed. Actionable stats can be drawn for developers to work on and capture the Android market. The data set that I have taken in this Projecct is a web scrapped data of 10 thousand Playstore applications to analyze the android competition.

# %% [markdown]
# #  *** Import Libraries ***

# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import style
# %matplotlib inline
import plotly.express as px
import warnings

# %%
df = pd.read_csv(r'/content/Play Store Data.csv')

# %% [markdown]
# #***All About Data ***

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (10841, 13)

# %%
df[10831:10835]
# Out:
#                             App             Category  Rating Reviews  Size  \
# 10831  payermonstationnement.fr  MAPS_AND_NAVIGATION     NaN      38  9.8M
# 10832                  FR Tides              WEATHER     3.8    1195  582k
# 10833               Chemin (fr)  BOOKS_AND_REFERENCE     4.8      44  619k
# 10834             FR Calculator               FAMILY     4.0       7  2.6M
#
#        Installs  Type Price Content Rating             Genres  \
# 10831    5,000+  Free     0       Everyone  Maps & Navigation
# 10832  100,000+  Free     0       Everyone            Weather
# 10833    1,000+  Free     0       Everyone  Books & Reference
# 10834      500+  Free     0       Everyone          Education
#
#             Last Updated Current Ver Android Ver
# 10831      June 13, 2018   2.0.148.0  4.0 and up
# 10832  February 16, 2014         6.0  2.1 and up
# 10833     March 23, 2014         0.8  2.2 and up
# 10834      June 18, 2017       1.0.0  4.1 and up

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.tail(2)
# Out:
#                                                  App             Category  \
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# 10839     Mature 17+  Books & Reference  January 19, 2015  Varies with device
# 10840       Everyone          Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 10839  Varies with device
# 10840  Varies with device

# %%
df.sample()
# Out:
#                                           App       Category  Rating Reviews  \
# 883  Movies by Flixster, with Rotten Tomatoes  ENTERTAINMENT     4.5  653008
#
#     Size     Installs  Type Price Content Rating         Genres  \
# 883  16M  10,000,000+  Free     0       Everyone  Entertainment
#
#       Last Updated Current Ver Android Ver
# 883  June 20, 2018       9.1.4  4.4 and up

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df.count()
# Out:
# App               10841
# Category          10841
# Rating             9367
# Reviews           10841
# Size              10841
# Installs          10841
# Type              10840
# Price             10841
# Content Rating    10840
# Genres            10841
# Last Updated      10841
# Current Ver       10833
# Android Ver       10838
# dtype: int64

# %%
df.Category.unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %% [markdown]
# #*** Data ***

# %%
# chack statistical data in data 
df.describe('')
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 50%       4.300000
# max      19.000000

# %%
# chack every rating 
df['Rating'].value_counts()
# Out:
# 4.4     1109
# 4.3     1076
# 4.5     1038
# 4.2      952
# 4.6      823
# 4.1      708
# 4.0      568
# 4.7      499
# 3.9      386
# 3.8      303
# 5.0      274
# 3.7      239
# 4.8      234
# 3.6      174
# 3.5      163
# 3.4      128
# 3.3      102
# 4.9       87
# 3.0       83
# 3.1       69
# 3.2       64
# 2.9       45
# 2.8       42
# 2.7       25
# 2.6       25
# 2.5       21
# 2.3       20
# 2.4       19
# 1.0       16
# 2.2       14
# 1.9       13
# 2.0       12
# 1.7        8
# 1.8        8
# 2.1        8
# 1.6        4
# 1.4        3
# 1.5        3
# 1.2        1
# 19.0       1
# Name: Rating, dtype: int64

# %%
# chack which is rows Rating is more than 5 
df[df.Rating>5]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
# we chack plot 
df.plot()
# Out:
# <Axes: >

# %%
# is thear null value in data  . 
df.isnull().values.any()
# Out:
# True

# %%
# how many null value in a data
df.isnull().sum().sum()
# Out:
# 1487

# %%
# howmany null values in which each category  
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
# where is null value in data    like true = null value
df.isnull()
# Out:
#          App  Category  Rating  Reviews   Size  Installs   Type  Price  \
# 0      False     False   False    False  False     False  False  False
# 1      False     False   False    False  False     False  False  False
# 2      False     False   False    False  False     False  False  False
# 3      False     False   False    False  False     False  False  False
# 4      False     False   False    False  False     False  False  False
# ...      ...       ...     ...      ...    ...       ...    ...    ...
# 10836  False     False   False    False  False     False  False  False
# 10837  False     False   False    False  False     False  False  False
# 10838  False     False    True    False  False     False  False  False
# 10839  False     False   False    False  False     False  False  False
# 10840  False     False   False    False  False     False  False  False
#
#        Content Rating  Genres  Last Updated  Current Ver  Android Ver
# ...

# %%
# information about the Data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
# information about the Data , deep memory usage of the dataframe .
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 8.3 MB

# %%
# is thear dublicate row in data 
df.duplicated().value_counts()
# Out:
# False    10358
# True       483
# dtype: int64

# %%
# dublicate App,Rating....etc in data
df.duplicated(['App','Category','Rating','Reviews','Size','Installs','Type','Price','Content Rating','Genres','Last Updated','Current Ver','Android Ver']).value_counts()
# Out:
# False    10358
# True       483
# dtype: int64

# %%
# dublicate in App data 
df.duplicated(['App']).value_counts()
# Out:
# False    9660
# True     1181
# dtype: int64

# %% [markdown]
# #*** Data Cleaning ***

# %%
# drop it use for a delete any row & column /  and we deleting 10472 cause  its outlier.

df.drop([10472], inplace = True )

"""
or if we shift one row move right side that time data will be ok but app name will not be thear .
thats why i drop that .
"""
# Out:
# '\nor if we shift one row move right side that time data will be ok but app name will not be thear .\nthats why i drop that .\n'

# %%
# manage null value 

# meanVal = df['Rating'].mean()
# df['Rating'].fillna(value=meanVal, inplace=True)
"""
if i manage null value of rating ,that rating will be show sutable data but it's fake,
thats why i didn't do that .
"""

# drop all null value of the data

df.dropna(inplace = True )

# %%
# Fixing & convert string data type to float  

# Price 
 
def fix_price(a) :
    try :
        if a.startswith('$') :
            return float(a[1:])
        elif a.startswith('Everyone') :
            return float(0)
        else :
            return float(a)
    except :
        return float(0)

df['Price'] = df['Price'].apply(fix_price)


# Installs

df['Installs'] = df.Installs.str.replace("+",'')
df['Installs'] = df['Installs'].apply(lambda x : str(x).replace (',','') if ',' in str(x) else str(x) )
df['Installs'] = df['Installs'].apply(lambda x : float(x))

# Reviews

df['Reviews'] = pd.to_numeric(df['Reviews'], errors='coerce')

# convert str to float 

index = df[df['Size']== '1,000+'].index
df.drop(axis=0,inplace=True, index=index)

S = [i for i in df['Size']]

def clean_sizes (sizes):

  Cleaned_data=[]

  for s in sizes:
    s = str(s)
    if 'M' in s:
      s = s.replace('M' , '')
      s=float(s)
      
      
    elif 'k' in s:
      s= s.replace('k', '')
      s=float(s)
      s= s/1024                   

    elif 'Varies with device' in s:
      s=float(0)
      

    Cleaned_data.append(s)

  return Cleaned_data
df['Size'] = clean_sizes(S)
df['Size']= df['Size'].astype(float)
# Out:
# <ipython-input-227-0b8fa0db8d0a>:21: FutureWarning:
#
# The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.

# %%
# drop null value .

df.dropna(inplace = True )

# %%
# Droping dublicates Row   

df.drop_duplicates(inplace=True)

# droping dublicates App

df.drop_duplicates(['App'],inplace=True)

# %%
# change name of column .

df.rename(columns = {'Price': 'Price $'} , inplace =True )
df.rename(columns = {'Size': 'Size M'} , inplace =True )

# %% [markdown]
# # *** Final Data ***

# %%
df.shape
# Out:
# (8190, 13)

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size M    Installs  Type  Price $ Content Rating  \
# 0      159    19.0     10000.0  Free      0.0       Everyone
# 1      967    14.0    500000.0  Free      0.0       Everyone
# 2    87510     8.7   5000000.0  Free      0.0       Everyone
# 3   215644    25.0  50000000.0  Free      0.0           Teen
# 4      967     2.8    100000.0  Free      0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# ...

# %%
df.sample()
# Out:
#                              App         Category  Rating  Reviews  Size M  \
# 4483  Materialistic P Wallpapers  PERSONALIZATION     4.8       24     3.6
#
#       Installs  Type  Price $ Content Rating           Genres    Last Updated  \
# 4483    1000.0  Free      0.0       Everyone  Personalization  August 3, 2018
#
#      Current Ver Android Ver
# 4483       2.244  5.0 and up

# %%
df.tail()
# Out:
#                                                  App             Category  \
# 10834                                  FR Calculator               FAMILY
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews  Size M    Installs  Type  Price $ Content Rating  \
# 10834     4.0        7     2.6       500.0  Free      0.0       Everyone
# 10836     4.5       38    53.0      5000.0  Free      0.0       Everyone
# 10837     5.0        4     3.6       100.0  Free      0.0       Everyone
# 10839     4.5      114     0.0      1000.0  Free      0.0     Mature 17+
# 10840     4.5   398307    19.0  10000000.0  Free      0.0       Everyone
#
#                   Genres      Last Updated         Current Ver  \
# ...

# %%
df.describe('')
# Out:
#             Rating       Reviews       Size M      Installs      Price $
# count  8190.000000  8.190000e+03  8190.000000  8.190000e+03  8190.000000
# mean      4.173321  2.554354e+05    18.660228  9.171613e+06     1.038342
# std       0.536691  1.986309e+06    22.381834  5.827170e+07    16.864040
# min       1.000000  1.000000e+00     0.000000  1.000000e+00     0.000000
# 50%       4.300000  3.009500e+03     9.400000  1.000000e+05     0.000000
# max       5.000000  7.815831e+07   100.000000  1.000000e+09   400.000000

# %%
df.plot()
# Out:
# <Axes: >

# %%
df[df.Rating>5]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size M, Installs, Type, Price $, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
df['Rating'].value_counts()
# Out:
# 4.3    897
# 4.4    894
# 4.5    847
# 4.2    809
# 4.6    683
# 4.1    620
# 4.0    512
# 4.7    442
# 3.9    359
# 3.8    286
# 5.0    271
# 3.7    224
# 4.8    221
# 3.6    167
# 3.5    156
# 3.4    126
# 3.3    100
# 4.9     85
# 3.0     81
# 3.1     69
# 3.2     62
# 2.9     45
# 2.8     40
# 2.6     24
# 2.7     23
# 2.5     20
# 2.3     20
# 2.4     19
# 1.0     16
# 2.2     14
# 2.0     12
# 1.9     11
# 1.7      8
# 1.8      8
# 2.1      8
# 1.6      4
# 1.4      3
# 1.5      3
# 1.2      1
# Name: Rating, dtype: int64

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size M            0
# Installs          0
# Type              0
# Price $           0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
df.isnull()
# Out:
#          App  Category  Rating  Reviews  Size M  Installs   Type  Price $  \
# 0      False     False   False    False   False     False  False    False
# 1      False     False   False    False   False     False  False    False
# 2      False     False   False    False   False     False  False    False
# 3      False     False   False    False   False     False  False    False
# 4      False     False   False    False   False     False  False    False
# ...      ...       ...     ...      ...     ...       ...    ...      ...
# 10834  False     False   False    False   False     False  False    False
# 10836  False     False   False    False   False     False  False    False
# 10837  False     False   False    False   False     False  False    False
# 10839  False     False   False    False   False     False  False    False
# 10840  False     False   False    False   False     False  False    False
#
#        Content Rating  Genres  Last Updated  Current Ver  Android Ver
# ...

# %%
df.duplicated().value_counts()
# Out:
# False    8190
# dtype: int64

# %%
df.duplicated(['App']).value_counts()
# Out:
# False    8190
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8190 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             8190 non-null   object
#  1   Category        8190 non-null   object
#  2   Rating          8190 non-null   float64
#  3   Reviews         8190 non-null   int64
#  4   Size M          8190 non-null   float64
#  5   Installs        8190 non-null   float64
#  6   Type            8190 non-null   object
#  7   Price $         8190 non-null   float64
#  8   Content Rating  8190 non-null   object
#  9   Genres          8190 non-null   object
#  10  Last Updated    8190 non-null   object
#  11  Current Ver     8190 non-null   object
#  12  Android Ver     8190 non-null   object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 895.8+ KB

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8190 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             8190 non-null   object
#  1   Category        8190 non-null   object
#  2   Rating          8190 non-null   float64
#  3   Reviews         8190 non-null   int64
#  4   Size M          8190 non-null   float64
#  5   Installs        8190 non-null   float64
#  6   Type            8190 non-null   object
#  7   Price $         8190 non-null   float64
#  8   Content Rating  8190 non-null   object
#  9   Genres          8190 non-null   object
#  10  Last Updated    8190 non-null   object
#  11  Current Ver     8190 non-null   object
#  12  Android Ver     8190 non-null   object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 4.6 MB

# %% [markdown]
# # *** Questions ***

# %% [markdown]
# #  Q.N. 1 = how many App category and each catogrey number of Apps on App store & also percentage .

# %%
len(df['Category'].value_counts())
# Out:
# 33

# %%
x = df.groupby(['Category'],as_index=False)['App'].count()
px.pie(x,values='App',names='Category',title='Percentage Of Each App Type').show()

print(' Apps Category in Google Play Store','\n',x.sort_values(by ='App',ascending =False))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Q.N. 2 = which is and how many each category number of Apps on App store .

# %%
df['Category'].value_counts()
# Out:
# FAMILY                 1607
# GAME                    912
# TOOLS                   717
# FINANCE                 302
# PRODUCTIVITY            301
# LIFESTYLE               301
# PERSONALIZATION         296
# MEDICAL                 290
# BUSINESS                263
# PHOTOGRAPHY             263
# SPORTS                  260
# COMMUNICATION           256
# HEALTH_AND_FITNESS      244
# NEWS_AND_MAGAZINES      204
# SOCIAL                  203
# TRAVEL_AND_LOCAL        187
# SHOPPING                180
# BOOKS_AND_REFERENCE     169
# VIDEO_PLAYERS           148
# DATING                  134
# MAPS_AND_NAVIGATION     118
# EDUCATION               118
# ENTERTAINMENT           102
# FOOD_AND_DRINK           94
# AUTO_AND_VEHICLES        73
# WEATHER                  72
# LIBRARIES_AND_DEMO       63
# HOUSE_AND_HOME           62
# ART_AND_DESIGN           60
# COMICS                   54
# PARENTING                50
# EVENTS                   45
# BEAUTY                   42
# ...

# %%
top = df.Category.value_counts().sort_values(ascending=False).head(33)
plt.figure(figsize=(16,8))
plt.xticks(rotation=75)
plt.title(' Categories ')
ylable = ('Number of App')
plt.style.use('bmh')
sns.barplot(x= top.index, y=top)
# Out:
# <Axes: title={'center': ' Categories '}, ylabel='Category'>

# %%
top = df.Category.value_counts().sort_values(ascending=True).head(33)
plt.figure(figsize=(16,8))
plt.xticks(rotation=75)
plt.title(' Categories ')
ylable = ('Number of App')
plt.style.use('bmh')
sns.barplot(x= top.index, y=top)
# Out:
# <Axes: title={'center': ' Categories '}, ylabel='Category'>

# %% [markdown]
# # Q.N. 3 = how many and which is 5 star Rating App on App store.

# %%
len(df[df['Rating'] == 5.0])
# Out:
# 271

# %%
df[df['Rating'] == 5.0]
# Out:
#                                               App   Category  Rating  Reviews  \
# 329                  Hojiboy Tojiboyev Life Hacks     COMICS     5.0       15
# 612                 American Girls Mobile Numbers     DATING     5.0        5
# 615                                  Awake Dating     DATING     5.0        2
# 633                         Spine- The dating app     DATING     5.0        5
# 636    Girls Live Talk - Free Text and Video Chat     DATING     5.0        6
# ...                                           ...        ...     ...      ...
# 10721                           Mad Dash Fo' Cash       GAME     5.0       14
# 10742                       GKPB FP Online Church  LIFESTYLE     5.0       32
# 10776                            Monster Ride Pro       GAME     5.0        1
# 10820                             Fr. Daoud Lamei     FAMILY     5.0       22
# 10837            Fr. Mike Schmitz Audio Teachings     FAMILY     5.0        4
#
# ...

# %% [markdown]
# # Q.N. 4 = how many and which is 1 star Rating App on App store.

# %%
len(df[df['Rating'] == 1.0])
# Out:
# 16

# %%
df[df['Rating'] == 1.0]
# Out:
#                                                     App       Category  \
# 625                             House party - live chat         DATING
# 4127                                  Speech Therapy: F         FAMILY
# 5151                                      Clarksburg AH        MEDICAL
# 5978                      Truck Driving Test Class 3 BC         FAMILY
# 6319                   BJ Bridge Standard American 2018           GAME
# 6490                                             MbH BM        MEDICAL
# 7144                                      CB Mobile Biz        FINANCE
# 7383                                     Thistletown CI   PRODUCTIVITY
# 7427                                     CJ DVD Rentals  COMMUNICATION
# 7806                                        CR Magazine       BUSINESS
# 7926                               Tech CU Card Manager        FINANCE
# 8820                                     DS Creator 2.0          TOOLS
# ...

# %% [markdown]
# # Q.N. 5 = how many Android Version & also how many app wornking on which android version on App store and it's percent .

# %%
len(df['Android Ver'].value_counts())
# Out:
# 31

# %%
df['Android Ver'].value_counts()
# Out:
# 4.1 and up            1811
# 4.0.3 and up          1141
# 4.0 and up            1040
# Varies with device     947
# 4.4 and up             713
# 2.3 and up             547
# 5.0 and up             447
# 4.2 and up             315
# 2.3.3 and up           232
# 2.2 and up             203
# 3.0 and up             201
# 4.3 and up             185
# 2.1 and up             112
# 1.6 and up              87
# 6.0 and up              42
# 7.0 and up              41
# 3.2 and up              31
# 2.0 and up              27
# 5.1 and up              16
# 1.5 and up              15
# 3.1 and up               8
# 2.0.1 and up             7
# 4.4W and up              5
# 8.0 and up               5
# 7.1 and up               3
# 4.0.3 - 7.1.1            2
# 5.0 - 8.0                2
# 1.0 and up               2
# 7.0 - 7.1.1              1
# 4.1 - 7.1.1              1
# 5.0 - 6.0                1
# Name: Android Ver, dtype: int64

# %%
x = df.groupby('Android Ver',as_index=False)['App'].count()
print('\n'*2+'android version and its percent'+'\n'*2)
px.pie(x,values='App',names='Android Ver',color='Android Ver',color_discrete_map={}).show()
# Out:
# android version and its percent
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
Type_cat = df.groupby('Category')['Android Ver'].value_counts().unstack().plot.barh(figsize=(10,18), width=1)
plt.show()

# %% [markdown]
# # Q.N. 6 = All paid and free number of Apps and its both percent also a most expensive App on App store .

# %%
print(df.groupby('Category')['Type'].value_counts())
# Out:
# Category           Type
# ART_AND_DESIGN     Free     57
#                    Paid      3
# AUTO_AND_VEHICLES  Free     72
#                    Paid      1
# BEAUTY             Free     42
#                           ...
# TRAVEL_AND_LOCAL   Paid      8
# VIDEO_PLAYERS      Free    144
#                    Paid      4
# WEATHER            Free     65
#                    Paid      7
# Name: Type, Length: 61, dtype: int64

# %%
amount = df.groupby(['Type','Category'],as_index=False)['App'].count()
px.sunburst(amount, values='App', path=['Type','Category'], 
            title='Amount Of App in Paid and Free Category',color='Category')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
x = df.groupby('Type',as_index=False)['App'].count()
print('\n'*2+'Most Of App In Google Play are Free'+'\n'*2)
px.pie(x,values='App',names='Type',color='Type',
       color_discrete_map={'Free':'purple','Paid':'yellow'}).show()
# Out:
# Most Of App In Google Play are Free
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
Type_cat = df.groupby('Category')['Type'].value_counts().unstack().plot.barh(figsize=(10,20), width=0.7)

# %%
df[df['Price $'] == df['Price $'].max()]
# Out:
#                            App   Category  Rating  Reviews  Size M  Installs  \
# 4367  I'm Rich - Trump Edition  LIFESTYLE     3.6      275     7.3   10000.0
#
#       Type  Price $ Content Rating     Genres Last Updated Current Ver  \
# 4367  Paid    400.0       Everyone  Lifestyle  May 3, 2018       1.0.1
#
#      Android Ver
# 4367  4.1 and up

# %% [markdown]
# # Q.N. 7 = Review on app store and each category Reviews .

# %%
len(df.Reviews)
# Out:
# 8190

# %%
plt.figure(figsize=(20,12))
plt.xticks(rotation=90)
plt.style.use('seaborn-deep')
plt.title('Category wise Reviews')
plt.xlabel('App Category')
plt.ylabel('Review per millions')
plt.bar(df.Category, df.Reviews , color=['black'])
# Out:
# <ipython-input-266-e7b1ede9cf76>:3: MatplotlibDeprecationWarning:
#
# The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
# <BarContainer object of 8190 artists>

# %%
g = sns.FacetGrid(df, col='Category', palette="Set1",  col_wrap=5, height=4)
g = (g.map(plt.hist, "Reviews", color="g"))

# %%
# Total reviews
plt.figure(figsize=(12,12))
sum_rew = df.groupby(['Category'])['Reviews'].sum().sort_values(ascending=False)
sns.barplot(x=sum_rew, y=sum_rew.index, data=df)
# Out:
# <Axes: xlabel='Reviews', ylabel='Category'>

# %% [markdown]
# # Q.N. 8 = Top 10 App on app store .

# %%
# Apps

Apps_df = df[df.Category!='App']
Apps_df.sort_values(by = ['Installs','Reviews', 'Rating' ], ascending = False)[['App','Installs','Reviews' , 'Rating', 'Type']].head(10)
# Out:
#                                            App      Installs   Reviews  \
# 2544                                  Facebook  1.000000e+09  78158306
# 336                         WhatsApp Messenger  1.000000e+09  69119316
# 2545                                 Instagram  1.000000e+09  66577313
# 335   Messenger – Text and Video Chat for Free  1.000000e+09  56642847
# 1654                            Subway Surfers  1.000000e+09  27722264
# 3665                                   YouTube  1.000000e+09  25655305
# 2808                             Google Photos  1.000000e+09  10858556
# 391              Skype - free IM & video calls  1.000000e+09  10484169
# 338               Google Chrome: Fast & Secure  1.000000e+09   9642995
# 3117                 Maps - Navigate & Explore  1.000000e+09   9235155
#
#       Rating  Type
# 2544     4.1  Free
# 336      4.4  Free
# 2545     4.5  Free
# 335      4.0  Free
# 1654     4.5  Free
# 3665     4.3  Free
# 2808     4.5  Free
# 391      4.1  Free
# ...

# %% [markdown]
# # Q.N. 9 = Top 10 game & social media app on app store .

# %%
# Games

game_df =df[df.Category=='GAME']
game_df.sort_values(by = ['Installs','Reviews', 'Rating'], ascending = False)[['App','Installs','Reviews', 'Rating', 'Type']].head(10)
# Out:
#                    App      Installs   Reviews  Rating  Type
# 1654    Subway Surfers  1.000000e+09  27722264     4.5  Free
# 1655  Candy Crush Saga  5.000000e+08  22426677     4.4  Free
# 1722    My Talking Tom  5.000000e+08  14891223     4.5  Free
# 1662               Pou  5.000000e+08  10485308     4.3  Free
# 1661      Temple Run 2  5.000000e+08   8118609     4.3  Free
# 1670    Clash of Clans  1.000000e+08  44891723     4.6  Free
# 1660      Clash Royale  1.000000e+08  23133508     4.6  Free
# 1675       8 Ball Pool  1.000000e+08  14198297     4.5  Free
# 1932    Shadow Fight 2  1.000000e+08  10979062     4.6  Free
# 1764        Pokémon GO  1.000000e+08  10424925     4.1  Free

# %%
# social 

social_df =df[df.Category=='SOCIAL']
social_df.sort_values(by = ['Installs','Reviews', 'Rating'], ascending = False)[['App','Installs','Reviews', 'Rating', 'Type']].head(10)
# Out:
#                                  App      Installs   Reviews  Rating  Type
# 2544                        Facebook  1.000000e+09  78158306     4.1  Free
# 2545                       Instagram  1.000000e+09  66577313     4.5  Free
# 2554                         Google+  1.000000e+09   4831125     4.2  Free
# 2550                        Snapchat  5.000000e+08  17014787     4.0  Free
# 2546                   Facebook Lite  5.000000e+08   8606259     4.3  Free
# 6373                              VK  1.000000e+08   5793284     3.8  Free
# 3945  Tik Tok - including musical.ly  1.000000e+08   5637451     4.4  Free
# 2552                       Pinterest  1.000000e+08   4305441     4.6  Free
# 2592    Tango - Live Video Broadcast  1.000000e+08   3806669     4.3  Free
# 2588  Badoo - Free Chat & Dating App  1.000000e+08   3781770     4.3  Free

# %% [markdown]
# # Q.N. 10 = All total install and each catogory installs on App store .

# %%
len((df['Installs'].value_counts()))
# Out:
# 19

# %%
df.Installs.unique()
# Out:
# array([1.e+04, 5.e+05, 5.e+06, 5.e+07, 1.e+05, 5.e+04, 1.e+06, 1.e+07,
#        5.e+03, 1.e+08, 1.e+09, 1.e+03, 5.e+08, 1.e+02, 5.e+02, 1.e+01,
#        5.e+00, 5.e+01, 1.e+00])

# %%
(df['Installs'].value_counts())
# Out:
# 1.000000e+06    1414
# 1.000000e+05    1094
# 1.000000e+04     986
# 1.000000e+07     937
# 1.000000e+03     696
# 5.000000e+06     607
# 5.000000e+05     503
# 5.000000e+04     456
# 5.000000e+03     424
# 1.000000e+02     303
# 5.000000e+07     202
# 5.000000e+02     199
# 1.000000e+08     188
# 1.000000e+01      69
# 5.000000e+01      56
# 5.000000e+08      24
# 1.000000e+09      20
# 5.000000e+00       9
# 1.000000e+00       3
# Name: Installs, dtype: int64

# %%
g = sns.FacetGrid(df, col='Category', palette="Set1",  col_wrap=5, height=4)
g = (g.map(plt.hist, "Installs", bins=5, color='c'))

# %% [markdown]
# # **Conclusion........**

# %% [markdown]
# # ** I Analyzed this data , and after Analyzing data i got to know that this dataset gives us so many intresting insights and useful info about the play store app & thus it will deliver useful info to the customers as well as will direct the developers to get new apps in market and to popularize the product.**

# %% [markdown]
# 1.---> On App store 33 category &  heighest (19.6 % ) of family
#          category on App store .
#
# 2.--->  Heighest number of apps of family categorys (1607)  on
#         App store and  samllest app caterory is beuty (42) apps.
#
# 3.--->  271 5 star rating app on app store .
#
# 4.--->  16 1 star rating app on app store .
#
# 5.---> App working 31 different type of  Android Version  and
#          1811 (22.1 % )  maximum app working on a 4.1 and up
#          Android Version .
#
# 6.--->  5588 App means  92.6 % free and  602 app means
#            7.35%  pain app avalable on app store .
#
# 7.---> Only 201 social media apps in social category but
#         heighest reviews on social category .
#
# 8.---> Facebook is a no. 1 App on App store .
#
# 9.--->  No 1 game is a Subway Surfers and no.1 social app is
#          facebook on store
#
# 10.---> Total 19 different type of install size of all apps on App
#           store
